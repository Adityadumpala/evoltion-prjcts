# %%
import pandas as pd 
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import warnings 
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv(r"C:\Users\Aditya\OneDrive\Desktop\WA_Fn-UseC_-HR-Employee-Attrition.csv")

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
#some of the features are hidden due to more no of features so we have see the missing features for better understanding of the data set 
hidden_features=data[['EnvironmentSatisfaction','Gender','HourlyRate','JobInvolvement','JobLevel','JobRole','JobSatisfaction','MaritalStatus','MonthlyIncome','MonthlyRate','NumCompaniesWorked','Over18','OverTime','PercentSalaryHike','PerformanceRating']]
hidden_features.head()
# Out:
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2  Female          94               3         2
# 1                        3    Male          61               2         2
# 2                        4    Male          92               2         1
# 3                        4  Female          56               3         1
# 4                        1    Male          40               3         1
#
#                  JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0        Sales Executive                4        Single           5993
# 1     Research Scientist                2       Married           5130
# 2  Laboratory Technician                3        Single           2090
# 3     Research Scientist                3       Married           2909
# 4  Laboratory Technician                2       Married           3468
#
#    MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# ...

# %%
hidden_features.tail()
# Out:
#       EnvironmentSatisfaction Gender  HourlyRate  JobInvolvement  JobLevel  \
# 1465                        3   Male          41               4         2
# 1466                        4   Male          42               2         3
# 1467                        2   Male          87               4         2
# 1468                        4   Male          63               2         2
# 1469                        2   Male          82               4         2
#
#                         JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 1465      Laboratory Technician                4       Married           2571
# 1466  Healthcare Representative                1       Married           9991
# 1467     Manufacturing Director                2       Married           6142
# 1468            Sales Executive                2       Married           5390
# 1469      Laboratory Technician                3       Married           4404
#
# ...

# %%
#shape of the data 
data.shape
# Out:
# (1470, 35)

# %%
#columns names
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
#null values count
data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
#data types of each columns
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# #some of the features are in the form of object dtype so first we have to convert them into numerical dtype

# %%
#object dtypes including target variable 
object_dtype=data.select_dtypes(include='object')
object_dtype
# Out:
#      Attrition     BusinessTravel              Department EducationField  \
# 0          Yes      Travel_Rarely                   Sales  Life Sciences
# 1           No  Travel_Frequently  Research & Development  Life Sciences
# 2          Yes      Travel_Rarely  Research & Development          Other
# 3           No  Travel_Frequently  Research & Development  Life Sciences
# 4           No      Travel_Rarely  Research & Development        Medical
# ...        ...                ...                     ...            ...
# 1465        No  Travel_Frequently  Research & Development        Medical
# 1466        No      Travel_Rarely  Research & Development        Medical
# 1467        No      Travel_Rarely  Research & Development  Life Sciences
# 1468        No  Travel_Frequently                   Sales        Medical
# 1469        No      Travel_Rarely  Research & Development        Medical
#
#       Gender                    JobRole MaritalStatus Over18 OverTime
# ...

# %% [markdown]
# #there are 8 features are in form of object dtype and targett variable also

# %%
data['EmployeeCount'].value_counts()
#EmployeeCount is having only 1 indicates that one employee so it not usefull for our prediction(nominal data)
#we can remove this feature
# Out:
# 1    1470
# Name: EmployeeCount, dtype: int64

# %%
data.drop('EmployeeCount',axis=1,inplace=True)

# %%
categorical_ftres=data[['Attrition','BusinessTravel','Department','Education','EducationField','EnvironmentSatisfaction','Gender','JobInvolvement','JobLevel','JobRole','JobSatisfaction','MaritalStatus','NumCompaniesWorked','Over18','OverTime','PerformanceRating','RelationshipSatisfaction','StandardHours','StockOptionLevel','TrainingTimesLastYear','WorkLifeBalance',]]

# %%
categorical_ftres
# Out:
#      Attrition     BusinessTravel              Department  Education  \
# 0          Yes      Travel_Rarely                   Sales          2
# 1           No  Travel_Frequently  Research & Development          1
# 2          Yes      Travel_Rarely  Research & Development          2
# 3           No  Travel_Frequently  Research & Development          4
# 4           No      Travel_Rarely  Research & Development          1
# ...        ...                ...                     ...        ...
# 1465        No  Travel_Frequently  Research & Development          2
# 1466        No      Travel_Rarely  Research & Development          1
# 1467        No      Travel_Rarely  Research & Development          3
# 1468        No  Travel_Frequently                   Sales          3
# 1469        No      Travel_Rarely  Research & Development          3
#
#      EducationField  EnvironmentSatisfaction  Gender  JobInvolvement  \
# ...

# %%
hidden_features.head(1)
# Out:
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2  Female          94               3         2
#
#            JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  MonthlyRate  \
# 0  Sales Executive                4        Single           5993        19479
#
#    NumCompaniesWorked Over18 OverTime  PercentSalaryHike  PerformanceRating
# 0                   8      Y      Yes                 11                  3

# %%
continuos_ftres=data[['Age','DailyRate','DistanceFromHome','HourlyRate','EmployeeNumber','MonthlyIncome','MonthlyRate','PercentSalaryHike','YearsInCurrentRole','YearsAtCompany','YearsSinceLastPromotion','YearsWithCurrManager','TotalWorkingYears']]
continuos_ftres
# Out:
#       Age  DailyRate  DistanceFromHome  HourlyRate  EmployeeNumber  \
# 0      41       1102                 1          94               1
# 1      49        279                 8          61               2
# 2      37       1373                 2          92               4
# 3      33       1392                 3          56               5
# 4      27        591                 2          40               7
# ...   ...        ...               ...         ...             ...
# 1465   36        884                23          41            2061
# 1466   39        613                 6          42            2062
# 1467   27        155                 4          87            2064
# 1468   49       1023                 2          63            2065
# 1469   34        628                 8          82            2068
#
#       MonthlyIncome  MonthlyRate  PercentSalaryHike  YearsInCurrentRole  \
# 0              5993        19479                 11                   4
# ...

# %%
data.shape
# Out:
# (1470, 34)

# %% [markdown]
# # univariate Analysis

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 1          2  Life Sciences               1
# 1                 8          1  Life Sciences               2
# 2                 2          2          Other               4
# 3                 3          4  Life Sciences               5
# 4                 2          1        Medical               7
#
#    EnvironmentSatisfaction  ... RelationshipSatisfaction  StandardHours  \
# 0                        2  ...                        1             80
# ...

# %% [markdown]
# observation:-
#
#     >>we can see age of 25 years to 50 years age of employees occuring most of the time and below 20years and above 55years employees are less  and aslo data is not skewed

# %%
plt.figure(figsize=(20,40))
plotnumber=1
for column in categorical_ftres:
    if plotnumber<=30:
        ax=plt.subplot(10,3,plotnumber)
        sns.countplot(categorical_ftres[column])
        plt.xlabel(column,fontsize=20)
        
    plotnumber+=1
    
plt.tight_layout()

# %%
observations:-
    1)attrition is a target variable it has imbalanced data 
    2)Bussiness Travel:-there are most of the employees are rarely traveled,and less employees are non travel category
    3)Department:-most of the employees are belongs to research and development department and next one is sales
    4)Education:-in this features 5 categories of education is there and category 3 education is occuring more no of times and 2,4 categories are also has high number comparing to 1 and 5
    5)
# Out:
#   File "<ipython-input-21-67739c49988e>", line 1
#     observations:-
#                   ^
# SyntaxError: invalid syntax

# %%
plt.figure(figsize=(20,10),facecolor='orange')
plotnumber=1
for column in continuos_ftres:
    if plotnumber<=16:
        ax=plt.subplot(4,4,plotnumber)
        sns.distplot(continuos_ftres[column])
        plt.xlabel(column,fontsize=20)
        
    plotnumber+=1
    
plt.tight_layout()

# %% [markdown]
# #observations:-

# %%
plt.figure(figsize=(15,8),facecolor='green')
plotnumber=1
for column in continuos_ftres:
    if plotnumber<=16:
        ax=plt.subplot(4,4,plotnumber)
        sns.boxplot(continuos_ftres[column])
        plt.xlabel(column,fontsize=20)
        
    plotnumber+=1
    
plt.tight_layout()

# %%
continuos_ftres.skew()
# Out:
# Age                        0.413286
# DailyRate                 -0.003519
# DistanceFromHome           0.958118
# HourlyRate                -0.032311
# EmployeeNumber             0.016574
# MonthlyIncome              1.369817
# MonthlyRate                0.018578
# PercentSalaryHike          0.821128
# YearsInCurrentRole         0.917363
# YearsAtCompany             1.764529
# YearsSinceLastPromotion    1.984290
# YearsWithCurrManager       0.833451
# TotalWorkingYears          1.117172
# dtype: float64

# %%
#skewed data is present in some features 
#i can use log transformation technique to normalize the data 
#before applying log let's check is there are any feature having zero values because log(o) is infinite it shows impact on furthur steps
print('disatance from home',data['DistanceFromHome'].unique())
print('\n')
print('monthly income',data['MonthlyIncome'].unique())
print('\n')
print('yearsincurrrole',data['YearsInCurrentRole'].unique())
print('\n')
print('years at company',data['YearsAtCompany'].unique())
print('\n')
print('years since last promotion',data['YearsSinceLastPromotion'].unique())
print('\n')
print('yearswithcurrManager',data['YearsWithCurrManager'].unique())
print('\n')
print('total workingyears',data['TotalWorkingYears'].unique())
# Out:
# disatance from home [ 1  8  2  3 24 23 27 16 15 26 19 21  5 11  9  7  6 10  4 25 12 18 29 22
#  14 20 28 17 13]
#
#
# monthly income [5993 5130 2090 ... 9991 5390 4404]
#
#
# yearsincurrrole [ 4  7  0  2  5  9  8  3  6 13  1 15 14 16 11 10 12 18 17]
#
#
# years at company [ 6 10  0  8  2  7  1  9  5  4 25  3 12 14 22 15 27 21 17 11 13 37 16 20
#  40 24 33 19 36 18 29 31 32 34 26 30 23]
#
#
# years since last promotion [ 0  1  3  2  7  4  8  6  5 15  9 13 12 10 11 14]
#
#
# yearswithcurrManager [ 5  7  0  2  6  8  3 11 17  1  4 12  9 10 15 13 16 14]
#
#
# total workingyears [ 8 10  7  6 12  1 17  5  3 31 13  0 26 24 22  9 19  2 23 14 15  4 29 28
#  21 25 20 11 16 37 38 30 40 18 36 34 32 33 35 27]

# %%
#observation:- yearsin curr role feature has 0 it is not makes sense because 0 means a person not spent his time as employee so we have to repalce zero into mean (continous data)
#same in yearsatcompany
#same in years since last promotion
#same in yearswithcurrmanager
#total working years also
data['YearsInCurrentRole']=data['YearsInCurrentRole'].replace(0,data['YearsInCurrentRole'].mean())
data['YearsAtCompany']=data['YearsAtCompany'].replace(0,data['YearsAtCompany'].mean())
data['YearsSinceLastPromotion']=data['YearsSinceLastPromotion'].replace(0,data['YearsSinceLastPromotion'].mean())
data['YearsWithCurrManager']=data['YearsWithCurrManager'].replace(0,data['YearsWithCurrManager'].mean())
data['TotalWorkingYears']=data['TotalWorkingYears'].replace(0,data['TotalWorkingYears'].mean())

# %%
print('disatance from home',data['DistanceFromHome'].unique())
print('\n')
print('monthly income',data['MonthlyIncome'].unique())
print('\n')
print('yearsincurrrole',data['YearsInCurrentRole'].unique())
print('\n')
print('years at company',data['YearsAtCompany'].unique())
print('\n')
print('years since last promotion',data['YearsSinceLastPromotion'].unique())
print('\n')
print('yearswithcurrManager',data['YearsWithCurrManager'].unique())
print('\n')
print('total workingyears',data['TotalWorkingYears'].unique())
# Out:
# disatance from home [ 1  8  2  3 24 23 27 16 15 26 19 21  5 11  9  7  6 10  4 25 12 18 29 22
#  14 20 28 17 13]
#
#
# monthly income [5993 5130 2090 ... 9991 5390 4404]
#
#
# yearsincurrrole [ 4.         7.         4.2292517  2.         5.         9.
#   8.         3.         6.        13.         1.        15.
#  14.        16.        11.        10.        12.        18.
#  17.       ]
#
#
# years at company [ 6.         10.          7.00816327  8.          2.          7.
#   1.          9.          5.          4.         25.          3.
#  12.         14.         22.         15.         27.         21.
#  17.         11.         13.         37.         16.         20.
#  40.         24.         33.         19.         36.         18.
#  29.         31.         32.         34.         26.         30.
#  23.        ]
#
#
# years since last promotion [ 2.1877551  1.         3.         2.         7.         4.
#   8.         6.         5.        15.         9.        13.
# ...

# %%
continuos_ftres.skew()
# Out:
# Age                        0.413286
# DailyRate                 -0.003519
# DistanceFromHome           0.958118
# HourlyRate                -0.032311
# EmployeeNumber             0.016574
# MonthlyIncome              1.369817
# MonthlyRate                0.018578
# PercentSalaryHike          0.821128
# YearsInCurrentRole         0.917363
# YearsAtCompany             1.764529
# YearsSinceLastPromotion    1.984290
# YearsWithCurrManager       0.833451
# TotalWorkingYears          1.117172
# dtype: float64

# %%
#now let's apply log for handle skewed data
data[['DistanceFromHome','MonthlyIncome','PercentSalaryHike','YearsInCurrentRole','YearsAtCompany','YearsSinceLastPromotion','YearsWithCurrManager','TotalWorkingYears']]=np.log(data[['DistanceFromHome','MonthlyIncome','PercentSalaryHike','YearsInCurrentRole','YearsAtCompany','YearsSinceLastPromotion','YearsWithCurrManager','TotalWorkingYears']])

# %%
skewed_ftrs=data[['DistanceFromHome','MonthlyIncome','PercentSalaryHike','YearsInCurrentRole','YearsAtCompany','YearsSinceLastPromotion','YearsWithCurrManager','TotalWorkingYears']]

# %%
skewed_ftrs.skew()
# Out:
# DistanceFromHome          -0.246004
# MonthlyIncome              0.286192
# PercentSalaryHike          0.494566
# YearsInCurrentRole        -0.098595
# YearsAtCompany            -0.337591
# YearsSinceLastPromotion    0.767394
# YearsWithCurrManager      -0.176733
# TotalWorkingYears         -0.879702
# dtype: float64

# %%
plt.figure(figsize=(20,10),facecolor='orange')
plotnumber=1
for column in skewed_ftrs:
    if plotnumber<=8:
        ax=plt.subplot(2,4,plotnumber)
        sns.distplot(skewed_ftrs[column])
        plt.xlabel(column,fontsize=20)
        
    plotnumber+=1
    
plt.tight_layout()

# %%
#two categories so using labelencoder is works better 
from sklearn.preprocessing import LabelEncoder
le_enc=LabelEncoder()

data['Attrition']=le_enc.fit_transform(data['Attrition'])
data['Gender']=le_enc.fit_transform(data['Gender'])
data['Over18']=le_enc.fit_transform(data['Over18'])
data['OverTime']=le_enc.fit_transform(data['OverTime'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 34 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int32
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   float64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeNumber            1470 non-null   int64
#  9   EnvironmentSatisfaction   1470 non-null   int64
#  10  Gender                    1470 non-null   int32
#  11  HourlyRate                1470 non-null   int64
#  12  JobInvolvement            1470 non-null   int64
#  13  JobLevel                  1470 non-null   int64
# ...

# %%
#object dtypes including target variable 
object_dtype=data.select_dtypes(include='object')
object_dtype
# Out:
#          BusinessTravel              Department EducationField  \
# 0         Travel_Rarely                   Sales  Life Sciences
# 1     Travel_Frequently  Research & Development  Life Sciences
# 2         Travel_Rarely  Research & Development          Other
# 3     Travel_Frequently  Research & Development  Life Sciences
# 4         Travel_Rarely  Research & Development        Medical
# ...                 ...                     ...            ...
# 1465  Travel_Frequently  Research & Development        Medical
# 1466      Travel_Rarely  Research & Development        Medical
# 1467      Travel_Rarely  Research & Development  Life Sciences
# 1468  Travel_Frequently                   Sales        Medical
# 1469      Travel_Rarely  Research & Development        Medical
#
#                         JobRole MaritalStatus
# 0               Sales Executive        Single
# 1            Research Scientist       Married
# 2         Laboratory Technician        Single
# ...

# %%
#categories more than two and not following an order 
data1=pd.get_dummies(object_dtype,drop_first=True)
data1
# Out:
#       BusinessTravel_Travel_Frequently  BusinessTravel_Travel_Rarely  \
# 0                                    0                             1
# 1                                    1                             0
# 2                                    0                             1
# 3                                    1                             0
# 4                                    0                             1
# ...                                ...                           ...
# 1465                                 1                             0
# 1466                                 0                             1
# 1467                                 0                             1
# 1468                                 1                             0
# 1469                                 0                             1
#
#       Department_Research & Development  Department_Sales  \
# 0                                     0                 1
# ...

# %%
df=pd.concat([data,data1],axis=1)
df
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0      41          1      Travel_Rarely       1102                   Sales
# 1      49          0  Travel_Frequently        279  Research & Development
# 2      37          1      Travel_Rarely       1373  Research & Development
# 3      33          0  Travel_Frequently       1392  Research & Development
# 4      27          0      Travel_Rarely        591  Research & Development
# ...   ...        ...                ...        ...                     ...
# 1465   36          0  Travel_Frequently        884  Research & Development
# 1466   39          0      Travel_Rarely        613  Research & Development
# 1467   27          0      Travel_Rarely        155  Research & Development
# 1468   49          0  Travel_Frequently       1023                   Sales
# 1469   34          0      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeNumber  \
# ...

# %%
#removing duplicate columns
df.drop(df.select_dtypes(include='object'),axis=1,inplace=True)

# %%
df
# Out:
#       Age  Attrition  DailyRate  DistanceFromHome  Education  EmployeeNumber  \
# 0      41          1       1102          0.000000          2               1
# 1      49          0        279          2.079442          1               2
# 2      37          1       1373          0.693147          2               4
# 3      33          0       1392          1.098612          4               5
# 4      27          0        591          0.693147          1               7
# ...   ...        ...        ...               ...        ...             ...
# 1465   36          0        884          3.135494          2            2061
# 1466   39          0        613          1.791759          1            2062
# 1467   27          0        155          1.386294          3            2064
# 1468   49          0       1023          0.693147          3            2065
# 1469   34          0        628          2.079442          3            2068
#
# ...

# %%
df.shape
# Out:
# (1470, 48)

# %%
#let's plot the heat map for checking correlation 

plt.figure(figsize=(50,15))
sns.heatmap(df.corr(),annot=True,annot_kws={'size':10})
plt.show()

# %%
#observation:-
#we can see monthlyincome and jobrole are highly +vely  correlated each other (0.95)

#and department&research and development and department sales are hihgly negatively correlated (-0.91)

#to remove one of the feature from monthlyincome and jobrole we can consider correlation with the label, which feature correlating less with the label we can remove that

#to remove one of the feature from  department&research and development and department sales we can consider correlation with the label,which feature correlating less with the label we can remove that

#after observing correlation with label monthly income is less correlation with the label so we remove monthlyincome
#research and development is less correlation with the label so we drop this feature also 
df.drop(['MonthlyIncome','Department_Research & Development'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (1470, 46)

# %%
df.head()
# Out:
#    Age  Attrition  DailyRate  DistanceFromHome  Education  EmployeeNumber  \
# 0   41          1       1102          0.000000          2               1
# 1   49          0        279          2.079442          1               2
# 2   37          1       1373          0.693147          2               4
# 3   33          0       1392          1.098612          4               5
# 4   27          0        591          0.693147          1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  ...  \
# 0                        2       0          94               3  ...
# 1                        3       1          61               2  ...
# 2                        4       1          92               2  ...
# 3                        4       0          56               3  ...
# 4                        1       1          40               3  ...
#
#    JobRole_Human Resources  JobRole_Laboratory Technician  JobRole_Manager  \
# ...

# %%
x=df.drop('Attrition',axis=1)
y=df['Attrition']

# %%
from imblearn.over_sampling import SMOTE

# %%
sm=SMOTE()
x,y=sm.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# 0    1233
# 1    1233
# Name: Attrition, dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler
scale=MinMaxScaler()

# %%
x=scale.fit_transform(x)

# %%
x
# Out:
# array([[0.54761905, 0.71581961, 0.        , ..., 0.        , 0.        ,
#         1.        ],
#        [0.73809524, 0.12670007, 0.6175405 , ..., 0.        , 1.        ,
#         0.        ],
#        [0.45238095, 0.90980673, 0.20584683, ..., 0.        , 0.        ,
#         1.        ],
#        ...,
#        [0.54761905, 0.23765211, 0.53793086, ..., 0.        , 0.        ,
#         0.        ],
#        [0.4047619 , 0.65569077, 0.66466231, ..., 0.        , 0.        ,
#         0.        ],
#        [0.23809524, 0.27057981, 0.77850121, ..., 0.        , 0.        ,
#         0.        ]])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
lr=LogisticRegression()

# %%
def best_randstate(clf):
    
#finding best random state 
    maxAccu=0
    maxRS=0
    for i in range(1,500):
        x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=i)
        clf.fit(x_train,y_train)
        predx=lr.predict(x_test)
        acc=accuracy_score(y_test,predx)
        if acc>maxAccu:
            maxAccu=acc
            maxRS=i
            print('best accuracy is',maxAccu,'on random_state',maxRS)

# %%
best_randstate(lr)
# Out:
# best accuracy is 0.8816855753646677 on random_state 1
# best accuracy is 0.9027552674230146 on random_state 3
# best accuracy is 0.9043760129659644 on random_state 9
# best accuracy is 0.9124797406807131 on random_state 15
# best accuracy is 0.9141004862236629 on random_state 26
# best accuracy is 0.9189627228525121 on random_state 81
# best accuracy is 0.9254457050243112 on random_state 153
# best accuracy is 0.9270664505672609 on random_state 351

# %%
#here the random state 198 is given best accuracy 
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=351)

# %%
def print_score(clf,x_train,x_test,y_train,y_test,train=True):
    if train:
        y_pred=clf.predict(x_train)
        print("\n==========train results============")
        print(f'accuracy score:{accuracy_score(y_train,y_pred)*100:2f}%')
        
    elif train==False:
        pred=clf.predict(x_test)
        print('\n=========test reslts===========')
        print(f'accuracy score is:{accuracy_score(y_test,pred)*100:2f}%')
        print('\n')
        print(confusion_matrix(y_test,pred))
        print('\n')
        print(classification_report(y_test,pred))
        scr=cross_val_score(clf,x,y,cv=20)
        print('cross validation score on lgistic regression is ',scr.mean())

# %%
# Logistic regression
lr=LogisticRegression()
lr.fit(x_train,y_train)

print_score(lr,x_train,x_test,y_train,y_test,train=True)
print_score(lr,x_train,x_test,y_train,y_test,train=False)
# Out:
# ==========train results============
# accuracy score:89.832342%
#
# =========test reslts===========
# accuracy score is:92.706645%
#
#
# [[300  13]
#  [ 32 272]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93       313
#            1       0.95      0.89      0.92       304
#
#     accuracy                           0.93       617
#    macro avg       0.93      0.93      0.93       617
# weighted avg       0.93      0.93      0.93       617
#
# cross validation score on lgistic regression is  0.8859592184631524

# %%
#KNeighborsClassifier
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
predx=knn.predict(x_test)
print('accuracy',accuracy_score(y_test,predx))
print(confusion_matrix(y_test,predx))
print(classification_report(y_test,predx))

#cross validation score on KNeighborsClassifier
scr=cross_val_score(knn,x,y, cv=10)
print('cross validation score of KNeighborsClassifier is',scr.mean())
# Out:
# accuracy 0.8946515397082658
# [[264  49]
#  [ 16 288]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.84      0.89       313
#            1       0.85      0.95      0.90       304
#
#     accuracy                           0.89       617
#    macro avg       0.90      0.90      0.89       617
# weighted avg       0.90      0.89      0.89       617
#
# cross validation score of KNeighborsClassifier is 0.8597445772028571

# %%
#DecisionTreeClassifier
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
predx=dt.predict(x_test)
print('accuracy',accuracy_score(y_test,predx))
print(confusion_matrix(y_test,predx))
print(classification_report(y_test,predx))


#cross validation score on decision tree classifier
scr=cross_val_score(dt,x,y, cv=10)
print('cross validation score of decision tree classifier is',scr.mean())
# Out:
# accuracy 0.8233387358184765
# [[252  61]
#  [ 48 256]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.81      0.82       313
#            1       0.81      0.84      0.82       304
#
#     accuracy                           0.82       617
#    macro avg       0.82      0.82      0.82       617
# weighted avg       0.82      0.82      0.82       617
#
# cross validation score of decision tree classifier is 0.7749975313518318

# %%
#RandomForestClassiffier
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
predx=rfc.predict(x_test)
print('accuracy',accuracy_score(y_test,predx))
print(confusion_matrix(y_test,predx))
print(classification_report(y_test,predx))

#cross validation score on random forestclassifier
scr=cross_val_score(rfc,x,y, cv=10)
print('cross validation score of random forestclassifier is',scr.mean())
# Out:
# accuracy 0.9416531604538088
# [[306   7]
#  [ 29 275]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94       313
#            1       0.98      0.90      0.94       304
#
#     accuracy                           0.94       617
#    macro avg       0.94      0.94      0.94       617
# weighted avg       0.94      0.94      0.94       617
#
# cross validation score of random forestclassifier is 0.9104670682334353

# %%
#SVC
from sklearn.svm import SVC
svc=SVC()
svc.fit(x_train,y_train)
predx=svc.predict(x_test)
print('accuracy',accuracy_score(y_test,predx))
print(confusion_matrix(y_test,predx))
print(classification_report(y_test,predx))

#cross validation score on SVC
scr=cross_val_score(svc,x,y, cv=10)
print('cross validation score of SVC is',scr.mean())
# Out:
# accuracy 0.93354943273906
# [[310   3]
#  [ 38 266]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.99      0.94       313
#            1       0.99      0.88      0.93       304
#
#     accuracy                           0.93       617
#    macro avg       0.94      0.93      0.93       617
# weighted avg       0.94      0.93      0.93       617
#
# cross validation score of SVC is 0.8991474934992265

# %%
from sklearn.metrics import roc_curve,roc_auc_score,plot_roc_curve

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=86,test_size=0.25)

# %%
###how well our model works on training data
disp=plot_roc_curve(lr,x_train,y_train)
plot_roc_curve(knn,x_train,y_train,ax=disp.ax_)
plot_roc_curve(dt,x_train,y_train,ax=disp.ax_)
plot_roc_curve(rfc,x_train,y_train,ax=disp.ax_)
plot_roc_curve(svc,x_train,y_train,ax=disp.ax_)

plt.legend(prop={'size':10},loc='lower right')
plt.show()

# %%
#lets see how well our model works on test data
disp=plot_roc_curve(lr,x_test,y_test)
plot_roc_curve(knn,x_test,y_test,ax=disp.ax_)
plot_roc_curve(dt,x_test,y_test,ax=disp.ax_)
plot_roc_curve(rfc,x_test,y_test,ax=disp.ax_)
plot_roc_curve(svc,x_test,y_test,ax=disp.ax_)

plt.legend(prop={'size':10},loc='lower right')
plt.show()

# %%
#Hyper parameter tunning
from sklearn.model_selection import GridSearchCV
#creating parameters list to pass in GridSearchCV
parameters= {'max_features':['auto','sqrt','log2'],
              'max_depth':[5,7,9,11,13,6,8],
              'criterion':['gini','entropy']}

# %%
Grdcv=GridSearchCV(RandomForestClassifier(),parameters,cv=10,scoring='accuracy')
Grdcv.fit(x_train,y_train)
Grdcv.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 13, 'max_features': 'log2'}

# %%
Grdcv_pred=Grdcv.best_estimator_.predict(x_test)#predicrting with best parameters
accuracy_score(y_test,Grdcv_pred)
# Out:
# 0.9270664505672609

# %%
#save the model
import pickle
filename='advertising_sales.pkl'
pickle.dump(Grdcv,open(filename,'wb'))

# %%
#conclusion
loaded_model= pickle.load(open('advertising_sales.pkl', 'rb'))
results=loaded_model.score(x_test,y_test)
print(results)
# Out:
# 0.9270664505672609
